# %% [markdown]
# # Deploy All Models to Azure ML
#
# Orchestrator notebook that deploys all 4 industry models to Azure ML endpoints in sequence:
# 1. Banking - credit risk model
# 2. Insurance - claim prediction model
# 3. Retail - customer churn model
# 4. Mining - equipment failure model
#
# **Prerequisites:**
# - Run `run_all_pipelines.ipynb` to train and log all models to MLflow
# - Azure ML workspace configured and accessible
# - Cluster: DBR ML 13.3+ with `mlflow` and `azure-ai-ml` installed

# %%
# %run ./_setup

# %% [markdown]
# ## Step 1: Deploy Banking

# %%
# %run ./banking/04_deploy_azure_ml

# %% [markdown]
# ## Step 2: Deploy Insurance

# %%
# %run ./insurance/04_deploy_azure_ml

# %% [markdown]
# ## Step 3: Deploy Retail

# %%
# %run ./retail/04_deploy_azure_ml

# %% [markdown]
# ## Step 4: Deploy Mining

# %%
# %run ./mining/04_deploy_azure_ml

# %% [markdown]
# ## Summary

# %%
print("All 4 industry models deployed to Azure ML successfully.")
