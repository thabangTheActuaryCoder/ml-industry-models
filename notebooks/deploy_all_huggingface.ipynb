# %% [markdown]
# # Deploy All Models to Hugging Face Hub
#
# Orchestrator notebook that pushes all 4 industry models to Hugging Face Hub in sequence:
# 1. Banking - credit scoring model
# 2. Insurance - fraud detection model
# 3. Retail - customer churn model
# 4. Mining - equipment failure model
#
# **Prerequisites:**
# - Run `run_all_pipelines.ipynb` to train all models first
# - `huggingface-hub` installed on the cluster
# - Databricks secret scope `huggingface` with key `token`, or `HF_TOKEN` env var

# %%
# %run ./_setup

# %% [markdown]
# ## Step 1: Deploy Banking

# %%
# %run ./banking/05_deploy_huggingface

# %% [markdown]
# ## Step 2: Deploy Insurance

# %%
# %run ./insurance/05_deploy_huggingface

# %% [markdown]
# ## Step 3: Deploy Retail

# %%
# %run ./retail/05_deploy_huggingface

# %% [markdown]
# ## Step 4: Deploy Mining

# %%
# %run ./mining/05_deploy_huggingface

# %% [markdown]
# ## Summary

# %%
print("All 4 industry models deployed to Hugging Face Hub successfully.")
print()
print("Repositories:")
print("  - https://huggingface.co/ThabangTheActuaryCoder/banking-credit-scoring-model")
print("  - https://huggingface.co/ThabangTheActuaryCoder/insurance-fraud-detection-model")
print("  - https://huggingface.co/ThabangTheActuaryCoder/retail-customer-churn-model")
print("  - https://huggingface.co/ThabangTheActuaryCoder/mining-equipment-failure-model")
